# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/Users/DELL/Desktop/PROJECT--@/sentimentdataset.csv')

# %%
data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# ...

# %%
data.tail()
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 727           728         732
# 728           729         733
# 729           730         734
# 730           731         735
# 731           732         736
#
#                                                   Text Sentiment  \
# 727  Collaborating on a science project that receiv...    Happy
# 728  Attending a surprise birthday party organized ...    Happy
# 729  Successfully fundraising for a school charity ...    Happy
# 730  Participating in a multicultural festival, cel...    Happy
# 731  Organizing a virtual talent show during challe...    Happy
#
#                Timestamp                                   User     Platform  \
# 727  2017-08-18 18:20:00       ScienceProjectSuccessHighSchool     Facebook
# 728  2018-06-22 14:15:00            BirthdayPartyJoyHighSchool    Instagram
# 729  2019-04-05 17:30:00   CharityFundraisingTriumphHighSchool      Twitter
# 730  2020-02-29 20:45:00    MulticulturalFestivalJoyHighSchool     Facebook
# ...

# %%
data.iloc[1]
# Out:
# Unnamed: 0.1                                                    1
# Unnamed: 0                                                      1
# Text             Traffic was terrible this morning.           ...
# Sentiment                                              Negative
# Timestamp                                     2023-01-15 08:45:00
# User                                                CommuterX
# Platform                                                Twitter
# Hashtags                #Traffic #Morning
# Retweets                                                      5.0
# Likes                                                        10.0
# Country                                                 Canada
# Year                                                         2023
# Month                                                           1
# Day                                                            15
# Hour                                                            8
# ...

# %%
data.shape
# Out:
# (732, 15)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  732 non-null    int64
#  1   Unnamed: 0    732 non-null    int64
#  2   Text          732 non-null    object
#  3   Sentiment     732 non-null    object
#  4   Timestamp     732 non-null    object
#  5   User          732 non-null    object
#  6   Platform      732 non-null    object
#  7   Hashtags      732 non-null    object
#  8   Retweets      732 non-null    float64
#  9   Likes         732 non-null    float64
#  10  Country       732 non-null    object
#  11  Year          732 non-null    int64
#  12  Month         732 non-null    int64
#  13  Day           732 non-null    int64
#  14  Hour          732 non-null    int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 85.9+ KB

# %%
data.shape[0]
# Out:
# 732

# %%
data.shape[1]
# Out:
# 15

# %%
data.describe()
# Out:
#        Unnamed: 0.1  Unnamed: 0    Retweets       Likes         Year  \
# count    732.000000  732.000000  732.000000  732.000000   732.000000
# mean     366.464481  369.740437   21.508197   42.901639  2020.471311
# std      211.513936  212.428936    7.061286   14.089848     2.802285
# min        0.000000    0.000000    5.000000   10.000000  2010.000000
# 25%      183.750000  185.750000   17.750000   34.750000  2019.000000
# 50%      366.500000  370.500000   22.000000   43.000000  2021.000000
# 75%      549.250000  553.250000   25.000000   50.000000  2023.000000
# max      732.000000  736.000000   40.000000   80.000000  2023.000000
#
#             Month         Day        Hour
# count  732.000000  732.000000  732.000000
# mean     6.122951   15.497268   15.521858
# std      3.411763    8.474553    4.113414
# min      1.000000    1.000000    0.000000
# 25%      3.000000    9.000000   13.000000
# 50%      6.000000   15.000000   16.000000
# 75%      9.000000   22.000000   19.000000
# ...

# %%
data.iloc[5]
# Out:
# Unnamed: 0.1                                                    5
# Unnamed: 0                                                      5
# Text             Feeling grateful for the little things in lif...
# Sentiment                                              Positive
# Timestamp                                     2023-01-16 09:10:00
# User                                                GratitudeNow
# Platform                                                Twitter
# Hashtags                  #Gratitude #PositiveVibes
# Retweets                                                     25.0
# Likes                                                        50.0
# Country                                                 India
# Year                                                         2023
# Month                                                           1
# Day                                                            16
# Hour                                                            9
# ...

# %%
data.loc[3]
# Out:
# Unnamed: 0.1                                                    3
# Unnamed: 0                                                      3
# Text             Excited about the upcoming weekend getaway!  ...
# Sentiment                                              Positive
# Timestamp                                     2023-01-15 18:20:00
# User                                                AdventureX
# Platform                                                Facebook
# Hashtags                #Travel #Adventure
# Retweets                                                      8.0
# Likes                                                        15.0
# Country                                                 UK
# Year                                                         2023
# Month                                                           1
# Day                                                            15
# Hour                                                           18
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  732 non-null    int64
#  1   Unnamed: 0    732 non-null    int64
#  2   Text          732 non-null    object
#  3   Sentiment     732 non-null    object
#  4   Timestamp     732 non-null    object
#  5   User          732 non-null    object
#  6   Platform      732 non-null    object
#  7   Hashtags      732 non-null    object
#  8   Retweets      732 non-null    float64
#  9   Likes         732 non-null    float64
#  10  Country       732 non-null    object
#  11  Year          732 non-null    int64
#  12  Month         732 non-null    int64
#  13  Day           732 non-null    int64
#  14  Hour          732 non-null    int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 85.9+ KB

# %%
data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#              Timestamp            User     Platform  \
# 0  2023-01-15 12:30:00   User123          Twitter
# 1  2023-01-15 08:45:00   CommuterX        Twitter
# 2  2023-01-15 15:45:00   FitnessFan      Instagram
# 3  2023-01-15 18:20:00   AdventureX       Facebook
# 4  2023-01-15 19:55:00   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# ...

# %% [markdown]
# # lineplot

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv('sentimentdataset.csv')

# Convert Timestamp to datetime object
data['Timestamp'] = pd.to_datetime(data['Timestamp'])

# Group by date and sentiment
daily_counts = data.groupby([data['Timestamp'].dt.date, 'Sentiment']).size().unstack(fill_value=0)

# Plot the lineplot
plt.figure(figsize=(14, 6))
daily_counts.plot(kind='line', marker='o', linewidth=2)
plt.title('Sentiment Trends Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Posts')
plt.legend(title='Sentiment', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_2548\439782124.py:21: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %% [markdown]
# # barplot

# %%
sentiment_counts = data['Sentiment'].value_counts()

# Plot as bar chart
plt.figure(figsize=(10, 6))
sentiment_counts.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Post Count by Sentiment')
plt.xlabel('Sentiment')
plt.ylabel('Number of Posts')
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid(axis='y')
plt.show()

# %% [markdown]
# # scatterplot

# %%
sns.scatterplot(x='Country',y='Sentiment',data=data)
plt.title('This is scatterplot')
plt.show()

# %%
# Out:
# <Axes: ylabel='Sentiment'>

# %% [markdown]
# # What is the overall distribution of sentiments (positive, negative, neutral) across the posts

# %%
# Define mapping to Positive, Negative, and Neutral
sentiment_map = {
    'Positive': 'Positive', 'Negative': 'Negative', 'Neutral': 'Neutral',
    'Joy': 'Positive', 'Love': 'Positive', 'Gratitude': 'Positive', 'Happiness': 'Positive',
    'Excitement': 'Positive', 'Admiration': 'Positive', 'Pride': 'Positive',
    'Amusement': 'Positive', 'Enjoyment': 'Positive', 'Contentment': 'Positive',
    'Affection': 'Positive', 'Awe': 'Positive', 'Surprise': 'Positive', 'Hope': 'Positive',
    'Enthusiasm': 'Positive', 'Inspiration': 'Positive', 'Confidence': 'Positive',
    'Curiosity': 'Positive', 'Kind': 'Positive', 'Calmness': 'Positive',

    'Sadness': 'Negative', 'Anger': 'Negative', 'Fear': 'Negative', 'Disgust': 'Negative',
    'Shame': 'Negative', 'Bitterness': 'Negative', 'Frustration': 'Negative',
    'Jealousy': 'Negative', 'Resentment': 'Negative', 'Loneliness': 'Negative',
    'Regret': 'Negative', 'Despair': 'Negative', 'Hate': 'Negative', 'Grief': 'Negative',
    'Anxiety': 'Negative', 'Apprehensive': 'Negative', 'Disappointed': 'Negative',
    'Helplessness': 'Negative', 'Envy': 'Negative', 'Devastated': 'Negative',
    'Bad': 'Negative', 'Heartbreak': 'Negative', 'Loss': 'Negative', 'Desolation': 'Negative',

    # Catch any unmapped entries
    'Happy': 'Positive', 'Sad': 'Negative'
}

# Apply the mapping
data['BroadSentiment'] = data['Sentiment'].map(sentiment_map).fillna('Other')

# %%
import matplotlib.pyplot as plt

# Count sentiments
sentiment_counts = data['BroadSentiment'].value_counts()

# Plot using one color or colormap to avoid color mismatch
plt.figure(figsize=(10, 6))
sentiment_counts.plot(kind='bar', color='cornflowerblue', edgecolor='black')
plt.title('Overall Distribution of Sentiments')
plt.xlabel('Sentiment Category')
plt.ylabel('Number of Posts')
plt.xticks(rotation=0)
plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# # conclusion
# * Positive sentiments dominate the dataset — the majority of posts express emotions like joy, gratitude, pride, excitement, and love. This suggests that users are largely using these platforms to share uplifting and emotionally expressive moments.
# * Negative sentiments are present in meaningful volume, encompassing feelings like sadness, anger, fear, frustration, and regret. These reflect emotional vulnerability or reactions to challenging events but are notably less common than positive ones.
# * Neutral sentiments make up a smaller slice of the total, mostly tied to informational, observational, or less emotionally charged posts.

# %% [markdown]
# #  Which platform generates the most engagement in terms of likes and retweets

# %%
# Load dataset if not already loaded
# data = pd.read_csv('sentimentdataset.csv')

# Group by platform and calculate average likes and retweets
engagement_stats = data.groupby('Platform')[['Likes', 'Retweets']].mean().sort_values(by='Likes', ascending=False)

# View results
print(engagement_stats)
# Out:
#                 Likes   Retweets
# Platform
# Twitter     45.382812  22.796875
# Instagram   45.089147  22.600775
# Facebook    41.870130  20.969697
# Twitter     37.304348  18.704348

# %%
# Plot average engagement by platform
engagement_stats.plot(kind='bar', figsize=(10, 6), color=['mediumseagreen', 'cornflowerblue'], edgecolor='black')
plt.title('Average Likes and Retweets by Platform')
plt.ylabel('Average Count')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# # conclusion
# * Based on the engagement analysis, Twitter generates the highest average likes and retweets, making it the most interactive platform in this dataset. Its design emphasizes rapid sharing and public reactions, which naturally boosts engagement compared to platforms like Facebook and Instagram. This highlights Twitter's strength as a hub for emotional expression and viral content diffusion.

# %% [markdown]
# #  Which users have the highest average engagement (likes and retweets per post)

# %%
# Group by user and calculate average likes and retweets
user_engagement = data.groupby('User')[['Likes', 'Retweets']].mean()

# Add a new column for total average engagement
user_engagement['AvgEngagement'] = user_engagement['Likes'] + user_engagement['Retweets']

# Sort by highest average engagement
top_users = user_engagement.sort_values(by='AvgEngagement', ascending=False)

# Display top 10 users
print(top_users.head(10))
# Out:
#                                   Likes  Retweets  AvgEngagement
# User
# AdeleConcertGoer                   80.0      40.0          120.0
# Bookworm                           80.0      40.0          120.0
# NatureEnthusiastSunsetWonder       80.0      40.0          120.0
# MovieEnthusiastPremiereAttendee    80.0      40.0          120.0
# BieberDanceEnthusiast              80.0      40.0          120.0
# SoccerFanTeamDefeats               80.0      40.0          120.0
# FitnessJunkie                      80.0      40.0          120.0
# FootballFanWorldCupCelebration     80.0      40.0          120.0
# SunshineDancer                     80.0      40.0          120.0
# ColorfulLaughter                   80.0      40.0          120.0

# %%
# Step 1: Group and calculate average engagement
user_stats = data.groupby('User')[['Likes', 'Retweets']].mean()
user_stats['AvgEngagement'] = user_stats['Likes'] + user_stats['Retweets']

# Step 2: Sort and pick top users
top_users = user_stats.sort_values(by='AvgEngagement', ascending=False).head(10)

# Step 3: Plot
plt.figure(figsize=(12, 6))
top_users['AvgEngagement'].plot(kind='barh', color='teal', edgecolor='black')
plt.title('Top 10 Users by Average Engagement (Likes + Retweets)')
plt.xlabel('Average Engagement per Post')
plt.ylabel('User')
plt.gca().invert_yaxis()  # Highest at top
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # conclusion
# * The analysis revealed that the users with the **highest average engagement** (likes + retweets per post) are standout voices in the dataset, consistently capturing audience attention. These users likely share compelling content, post at optimal times, or maintain a strong follower base—making them key influencers in their respective platforms and valuable for trendsetting or campaign amplification.
